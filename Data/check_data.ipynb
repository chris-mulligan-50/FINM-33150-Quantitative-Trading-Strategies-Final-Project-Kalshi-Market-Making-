# %%
import pandas as pd

df = pd.read_parquet("Kalshi_kxinx_clean.parquet")

# %%
df.head()
# Out:
#          date                    ticker  \
# 0  2026-01-02  KXINX-26JAN02H1600-B6787
# 1  2026-01-02  KXINX-26JAN02H1600-B6787
# 2  2026-01-02  KXINX-26JAN02H1600-B6787
# 3  2026-01-02  KXINX-26JAN02H1600-B6787
# 4  2026-01-02  KXINX-26JAN02H1600-B6787
#
#                                     contract_desc  bracket_floor  bracket_cap  \
# 0  KXINX: SPX in [6775.0, 6800.0)  exp 2026-01-02         6775.0       6800.0
# 1  KXINX: SPX in [6775.0, 6800.0)  exp 2026-01-02         6775.0       6800.0
# 2  KXINX: SPX in [6775.0, 6800.0)  exp 2026-01-02         6775.0       6800.0
# 3  KXINX: SPX in [6775.0, 6800.0)  exp 2026-01-02         6775.0       6800.0
# 4  KXINX: SPX in [6775.0, 6800.0)  exp 2026-01-02         6775.0       6800.0
#
#   side_of_close                               ts  price  quantity  direction  \
# 0         below 2026-01-01 19:27:55.835333-05:00   0.41      15.0  yes_taker
# 1         below 2026-01-01 21:46:31.683290-05:00   0.41      23.0  yes_taker
# ...
